# %%
# treat this code as a server code which is in prodution for now, and we get any new
# data inputs then we need to preprocess everything manually and even after doing so still we can have issues in future after
